# %%
NN = 251
q = 128
df = 73
dg = 71

R1.<t> = PolynomialRing(ZZ)
ideal = t**NN - 1
Rt = R1.quotient_by_principal_ideal(ideal)

print (Rt)

def gen_fg(R, d):
    print (d)
    while True:
        f = R.random_element()._polynomial
        coef = f.coefficients()
        l = len([x for x in coef if x != 0])
        if l < 100:
            print ('!' + str(l))
        if l == d:
            print (f)
            return f
        
f = gen_fg(Rt, df) #Rt.random_element()._polynomial
g = gen_fg(Rt, dg) #Rt.random_element()._polynomial

print (f)
print (g)
a = b +1

f_res = f.resultant(t**NN-1)
g_res = g.resultant(t**NN-1)

ffff = 0
for i in range(NN):
    ffff += t**i
ffff = Rt(ffff)._polynomial

Rf = f_res % ffff
Rg = g_res % ffff

_,alpha,beta = xgcd(Rf, Rg)

def gen_p(f):
    test = 1
    for i in range(2, NN):
        test *= Rt(f(t**i))
        test = test.mod(ffff)
        print (i)
    return test

pf = gen_p(f)
pg = gen_p(g)
    
F = Rt(-q * beta * pg)
G = Rt(q*alpha*pf)

print (q)
print (f*G - g*F)

    
# print (test % ffff._polynomial)
#     #test = Rt(test)._polynomial % ffff
#     #print (test)

    
# print (test)

# R.<x> = PolynomialRing(ZZ)
# S.<xbar> = R.quo(t**NN-1)

# f = S.random_element()._polynomial
# g = S.random_element()._polynomial


# ffff = 0
# for i in range(NN):
#     ffff += x**i
# ffff = S(ffff)

# f_res = S(f.resultant(x**NN-1))
# #g_res = g.resultant(x**NN-1) % ffff

# print (f_res)

# test = 1
# print (f(x**i))
# print (dir(f(x**i)))
# for i in range(1, NN):
#     test *= f(x**i) % ffff
    
# print (test)

# while True:
#     F = S.random_element()._polynomial
#     G = S.random_element()._polynomial
#     if f*G - g*F == S(q):
#         print ('wow')
#         break

# NN = 4
# q = 2

# R1.<x> = PolynomialRing(ZZ)
# ideal = x**NN - 1
# Rx = R1.quotient_by_principal_ideal(ideal)
# print (Rx)

# f = Rx.random_element()
# g = Rx.random_element()

# F = Rx.random_element()
# G = Rx.random_element()

# print (Rx.order())
# print (type(f))
# print (f(5))
# print (f.degree())

# while True:
#     F = Rx.random_element()
#     G = Rx.random_element()
#     if f*G - F*g == Rx(q):
#         break

# print ('wow')
# Out:
# Univariate Quotient Polynomial Ring in tbar over Integer Ring with modulus t^251 - 1
# 73
